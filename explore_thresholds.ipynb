# %% [markdown]
# # Exploring Fuzzy Match Thresholds
#
# This notebook analyzes incorrect deduplication results to find the minimum thresholds needed to avoid false matches.

# %%
import pandas as pd
from rapidfuzz import fuzz
from itertools import combinations

# %%
# Load the incorrect dedupes
df = pd.read_csv("output/incorrect_dedupes.csv")
df.head()
# Out:
#                  representative_name  \
# 0  Santa Clara County Ordinance Code
# 1              County Health Officer
# 2                  Ord. No. NS-304.1
# 3            Chief Operating Officer
# 4                   Ord. No. NS-3.16
#
#                                entity_name_varieties                types  \
# 0  County of Santa Clara Ordinance Code | Ordinan...  organization, other
# 1  County Health Officer | County Public Health O...                 role
# 2  Ord. No. NS-1004.121 | Ord. No. NS-1100.113 | ...                other
# 3  Chief Operating Officer | Chief Probation Officer                 role
# 4  Ord. No. NS-3.16 | Ord. No. NS-3.19 | Ord. No....                other
#
#    num_sections                                      Unnamed: 4
# 0            15  Santa Clara County Ordinance Code Division A37
# 1            12                           Deputy Health Officer
# 2            11                             Many incongruencies
# 3            10                         Chief Probation Officer
# 4             9                             Many incongruencies

# %%
def normalize_entity_name(name: str) -> str:
    """Same normalization as fuzzy_match.py"""
    return name.lower().strip()


def get_max_similarity(varieties_str: str) -> dict:
    """
    For a pipe-separated list of entity name varieties,
    calculate all pairwise similarities and return info about the max.
    """
    varieties = [v.strip() for v in varieties_str.split("|")]
    
    if len(varieties) < 2:
        return {"max_score": None, "pair": None, "all_scores": []}
    
    all_scores = []
    max_score = 0
    max_pair = None
    
    for name1, name2 in combinations(varieties, 2):
        score = fuzz.token_sort_ratio(
            normalize_entity_name(name1),
            normalize_entity_name(name2)
        )
        all_scores.append((name1, name2, score))
        if score > max_score:
            max_score = score
            max_pair = (name1, name2)
    
    return {
        "max_score": max_score,
        "max_pair": max_pair,
        "all_scores": all_scores,
        "num_varieties": len(varieties)
    }

# %%
# Calculate similarities for each incorrect group
results = []

# Filter to entities with only 2 varieties
df = df[df["entity_name_varieties"].str.count(r"\|") == 1]

for idx, row in df.iterrows():
    info = get_max_similarity(row["entity_name_varieties"])
    results.append({
        "representative_name": row["representative_name"],
        "max_score": info["max_score"],
        "max_pair": info["max_pair"],
        "num_varieties": info["num_varieties"],
        "all_scores": info["all_scores"]
    })

results_df = pd.DataFrame(results)
results_df = results_df.sort_values("max_score", ascending=False)
results_df.head(20)
# Out:
#                                representative_name  max_score  \
# 40         26 United States Code Section 501(c)(3)  97.435897
# 12          Code of Civil Procedure Section 1094.6  96.202532
# 44                        Class 1 Electric Bicycle  95.833333
# 51  Special Event Permit for a Major Special Event  95.652174
# 52               Trimble Road (west of State Route  94.117647
# 37                               SUPPLEMENT NO. 43  94.117647
# 50                                Section 1207.1.5  93.750000
# 31    Health and Safety Code Section 18860 et seq.  92.134831
# 24              California Building Standards Code  91.891892
# 23                                    CHAPTER 2.40  91.666667
# 26                                    Chapter 3.10  91.666667
# 28                         Civil Code Section 1351  91.304348
# 46                    FEMA Technical Bulletin 1-93  91.228070
# 48                                           LOT 2  90.909091
# 19                                     Mary Avenue  90.909091
# 10              Santa Clara County Fire Department  90.666667
# 41                           Bridge No. 94002-2.38  90.476190
# 27            Chapter 3.50 of the Zoning Ordinance  90.410959
# 30        County Noise Element of the General Plan  90.243902
# 25        California Government Code Section 25132  90.243902
#
#                                              max_pair  num_varieties  \
# 40  (26 United States Code Section 501(c)(3), 26 U...              2
# 12  (Code of Civil Procedure Section 1094.6, Code ...              2
# 44  (Class 1 Electric Bicycle, Class 2 Electric Bi...              2
# 51  (Special Event Permit for a Major Special Even...              2
# 52  (Trimble Road (east of State Route 1, Trimble ...              2
# 37             (SUPPLEMENT NO. 43, SUPPLEMENT NO. 44)              2
# 50               (Section 1207.1.5, Section 1207.5.5)              2
# 31  (Health and Safety Code Section 119300 et seq....              2
# 24  (California Building Standards Code, Californi...              2
# 23                       (CHAPTER 2.40, Chapter 5.40)              2
# 26                       (Chapter 3.10, Chapter 3.20)              2
# 28  (Civil Code Section 1351, Civil Code Section 5...              2
# 46  (FEMA Technical Bulletin 1-93, FEMA Technical ...              2
# 48                                    (LOT 2, LOT 20)              2
# 19                         (Mary Avenue, Omar Avenue)              2
# 10  (Chief, Santa Clara County Fire Department, Sa...              2
# 41     (Bridge No. 94002-2.38, Bridge No. 94002-3.13)              2
# 27  (Chapter 3.50 of the Zoning Ordinance, Chapter...              2
# 30  (County Noise Element of the General Plan, Hou...              2
# 25  (California Government Code Section 25132, Cal...              2
#
#                                            all_scores
# 40  [(26 United States Code Section 501(c)(3), 26 ...
# 12  [(Code of Civil Procedure Section 1094.6, Code...
# 44  [(Class 1 Electric Bicycle, Class 2 Electric B...
# 51  [(Special Event Permit for a Major Special Eve...
# 52  [(Trimble Road (east of State Route 1, Trimble...
# 37  [(SUPPLEMENT NO. 43, SUPPLEMENT NO. 44, 94.117...
# 50      [(Section 1207.1.5, Section 1207.5.5, 93.75)]
# 31  [(Health and Safety Code Section 119300 et seq...
# 24  [(California Building Standards Code, Californ...
# 23  [(CHAPTER 2.40, Chapter 5.40, 91.66666666666666)]
# 26  [(Chapter 3.10, Chapter 3.20, 91.66666666666666)]
# 28  [(Civil Code Section 1351, Civil Code Section ...
# 46  [(FEMA Technical Bulletin 1-93, FEMA Technical...
# 48                [(LOT 2, LOT 20, 90.9090909090909)]
# 19     [(Mary Avenue, Omar Avenue, 90.9090909090909)]
# 10  [(Chief, Santa Clara County Fire Department, S...
# 41  [(Bridge No. 94002-2.38, Bridge No. 94002-3.13...
# 27  [(Chapter 3.50 of the Zoning Ordinance, Chapte...
# 30  [(County Noise Element of the General Plan, Ho...
# 25  [(California Government Code Section 25132, Ca...

# %% [markdown]
# ## Key Finding: Required Threshold
#
# To avoid ALL incorrect matches, the threshold must be **higher than the maximum similarity score** found above.

# %%
max_incorrect_score = results_df["max_score"].max()
print(f"Highest similarity score among incorrect matches: {max_incorrect_score}")
print(f"Required threshold to avoid ALL incorrect matches: > {max_incorrect_score}")

# %%
# Distribution of max scores
print("Distribution of max similarity scores in incorrect groups:\n")
print(results_df["max_score"].describe())

# %%
# How many incorrect matches would be avoided at different thresholds?
thresholds = [86, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99, 100]

print("Incorrect matches avoided at different thresholds:\n")
print(f"{'Threshold':<12} {'Avoided':<12} {'Remaining':<12} {'% Avoided'}")
print("-" * 50)

total = len(results_df)
for thresh in thresholds:
    avoided = (results_df["max_score"] < thresh).sum()
    remaining = total - avoided
    pct = (avoided / total) * 100
    print(f"{thresh:<12} {avoided:<12} {remaining:<12} {pct:.1f}%")

# %% [markdown]
# ## Detailed View: Highest Scoring Incorrect Pairs
#
# These are the hardest cases to separate - pairs that are very similar but should NOT be matched.

# %%
# Show the top problematic pairs
print("Top 20 incorrect matches by similarity score:\n")
for idx, row in results_df.head(20).iterrows():
    print(f"Score: {row['max_score']}")
    print(f"  Representative: {row['representative_name']}")
    if row['max_pair']:
        print(f"  Highest pair: '{row['max_pair'][0]}' <-> '{row['max_pair'][1]}'")
    print()

# %%
# Histogram of scores
try:
    import matplotlib.pyplot as plt
    
    plt.figure(figsize=(10, 6))
    plt.hist(results_df["max_score"].dropna(), bins=20, edgecolor="black")
    plt.axvline(x=85, color="red", linestyle="--", label="Current threshold (85)")
    plt.xlabel("Max Similarity Score")
    plt.ylabel("Number of Incorrect Groups")
    plt.title("Distribution of Max Similarity Scores in Incorrect Dedupes")
    plt.legend()
    plt.show()
except ImportError:
    print("matplotlib not installed - skipping histogram")

# %% [markdown]
# ## All Pairwise Scores
#
# Flatten all pairwise comparisons to see the full picture.

# %%
# Flatten all pairwise scores
all_pairs = []
for idx, row in results_df.iterrows():
    for name1, name2, score in row["all_scores"]:
        all_pairs.append({
            "representative": row["representative_name"],
            "name1": name1,
            "name2": name2,
            "score": score
        })

pairs_df = pd.DataFrame(all_pairs)
pairs_df = pairs_df.sort_values("score", ascending=False)
print(f"Total pairwise comparisons: {len(pairs_df)}")
pairs_df.head(30)

# %%
# How many pairs exceed the current threshold?
above_85 = (pairs_df["score"] >= 85).sum()
print(f"Pairs with score >= 85: {above_85}")
print(f"Pairs with score < 85: {len(pairs_df) - above_85}")
